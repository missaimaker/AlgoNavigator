# %%
import matplotlib.pyplot as plt
import pandas

def return_csv_list(csv_file):
    csv_data = pandas.read_csv(csv_file)
    
    return csv_data["K"].to_list(), csv_data["Average Time (ms)"].to_list()
    
def single_plot(k_values, avg_times, title, plot_type):
    if plot_type == "Line":
        plt.plot(k_values, avg_times)
    elif plot_type == "Scatter":
        plt.scatter(k_values, avg_times)

    plt.title(title)
    plt.xlabel("K Value")
    plt.ylabel("Average Time (ms)")
    #plt.grid(True)
    plt.show()
    
def multiple_line_plot(k_values_list, avg_times_list, title, labels, plot_type):
    for i in range(len(k_values_list)):
        
        if plot_type == "Line":
            plt.plot(k_values_list[i], avg_times_list[i], label=labels[i])
        if plot_type == "Scatter":
            plt.scatter(k_values_list[i], avg_times_list[i], label=labels[i])
    
    plt.title(title)
    plt.xlabel("K Value")
    plt.ylabel("Average Time (ms)")
    #plt.grid(True)
    plt.legend()
    plt.show()
        

#Displays graphs to answer Deliverable 1.2 (UNSORTED RESULTS)
def unsorted_deliverable_1_2():
    csv_data1 = return_csv_list("deliverable_1.2_csv/unsorted_csvs/100k.csv")
    csv_data2 = return_csv_list("deliverable_1.2_csv/unsorted_csvs/250k.csv")
    csv_data3 = return_csv_list("deliverable_1.2_csv/unsorted_csvs/500k.csv")
    csv_data4 = return_csv_list("deliverable_1.2_csv/unsorted_csvs/750k.csv")
    csv_data5 = return_csv_list("deliverable_1.2_csv/unsorted_csvs/1000k.csv")


    k_values = [csv_data1[0], csv_data2[0], csv_data3[0], csv_data4[0], csv_data5[0]]
    avg_times = [csv_data1[1], csv_data2[1], csv_data3[1], csv_data4[1], csv_data5[1]]
    labels = ["n=100,000", "n=250,000", "n=500,000", "n=750,000", "n=1,000,000"]

    multiple_line_plot(k_values, avg_times, "Hybrid Sort Performance (Unsorted Avg)", labels, "Line")
    multiple_line_plot(k_values, avg_times, "Hybrid Sort Performance (Unsorted Avg)", labels, "Scatter")

#Displays graphs to answer Deliverable 1.2 (SORTED RESULTS)
def sorted_deliverable_1_2():
    csv_data1 = return_csv_list("deliverable_1.2_csv/sorted_csvs/100k.csv")
    csv_data2 = return_csv_list("deliverable_1.2_csv/sorted_csvs/250k.csv")
    csv_data3 = return_csv_list("deliverable_1.2_csv/sorted_csvs/500k.csv")
    csv_data4 = return_csv_list("deliverable_1.2_csv/sorted_csvs/750k.csv")
    csv_data5 = return_csv_list("deliverable_1.2_csv/sorted_csvs/1000k.csv")

    k_values = [csv_data1[0], csv_data2[0], csv_data3[0], csv_data4[0], csv_data5[0]]
    avg_times = [csv_data1[1], csv_data2[1], csv_data3[1], csv_data4[1], csv_data5[1]]
    labels = ["n=100,000", "n=250,000", "n=500,000", "n=750,000", "n=1,000,000"]

    multiple_line_plot(k_values, avg_times, "Hybrid Sort Performance (Sorted Avg)", labels, "Line")
    multiple_line_plot(k_values, avg_times, "Hybrid Sort Performance (Sorted Avg)", labels, "Scatter")


unsorted_deliverable_1_2()
sorted_deliverable_1_2()

# %%
import matplotlib.pyplot as plt
import pandas


def return_csv_list(csv_file, key1):
    csv_data = pandas.read_csv(csv_file)
    
    return csv_data[key1].to_list(), csv_data["Average Time (ms)"].to_list()
    
def single_plot(k_values, avg_times, title, plot_type, xlabel):
    if plot_type == "Line":
        plt.plot(k_values, avg_times)
    elif plot_type == "Scatter":
        plt.scatter(k_values, avg_times)

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel("Average Time (ms)")
    plt.show()
    
def multiple_line_plot(k_values_list, avg_times_list, title, labels, plot_type):
    for i in range(len(k_values_list)):
        
        if plot_type == "Line":
            plt.plot(k_values_list[i], avg_times_list[i], label=labels[i])
        if plot_type == "Scatter":
            plt.scatter(k_values_list[i], avg_times_list[i], label=labels[i])
    
    plt.title(title)
    plt.xlabel("K Value")
    plt.ylabel("Average Time (ms)")
    #plt.grid(True)
    plt.legend()
    plt.show()
        

#Displays graphs to answer Deliverable 1.2 (UNSORTED RESULTS)
def unsorted_deliverable_1_2():
    csv_data1 = return_csv_list("unsorted_csvs/100k.csv", "K")
    csv_data2 = return_csv_list("unsorted_csvs/250k.csv", "K")
    csv_data3 = return_csv_list("unsorted_csvs/500k.csv", "K")
    csv_data4 = return_csv_list("unsorted_csvs/750k.csv", "K")
    csv_data5 = return_csv_list("unsorted_csvs/1000k.csv", "K")

    k_values = [csv_data1[0], csv_data2[0], csv_data3[0], csv_data4[0], csv_data5[0]]
    avg_times = [csv_data1[1], csv_data2[1], csv_data3[1], csv_data4[1], csv_data5[1]]
    labels = ["n=100,000", "n=250,000", "n=500,000", "n=750,000", "n=1,000,000"]

    multiple_line_plot(k_values, avg_times, "Hybrid Sort Performance (Unsorted Avg)", labels, "Line")
    multiple_line_plot(k_values, avg_times, "Hybrid Sort Performance (Unsorted Avg)", labels, "Scatter")

#Displays graphs to answer Deliverable 1.2 (SORTED RESULTS)
def sorted_deliverable_1_2():
    csv_data1 = return_csv_list("sorted_csvs/100k.csv", "K")
    csv_data2 = return_csv_list("sorted_csvs/250k.csv", "K")
    csv_data3 = return_csv_list("sorted_csvs/500k.csv", "K")
    csv_data4 = return_csv_list("sorted_csvs/750k.csv", "K")
    csv_data5 = return_csv_list("sorted_csvs/1000k.csv", "K")

    k_values = [csv_data1[0], csv_data2[0], csv_data3[0], csv_data4[0], csv_data5[0]]
    avg_times = [csv_data1[1], csv_data2[1], csv_data3[1], csv_data4[1], csv_data5[1]]
    labels = ["n=100,000", "n=250,000", "n=500,000", "n=750,000", "n=1,000,000"]

    multiple_line_plot(k_values, avg_times, "Hybrid Sort Performance (Sorted Avg)", labels, "Line")
    multiple_line_plot(k_values, avg_times, "Hybrid Sort Performance (Sorted Avg)", labels, "Scatter")


def unsorted_deliverable_1_3():
    csv_data = return_csv_list("deliverable_1.3_csv/unsorted_csvs/values.csv", "N") #might need to change to full path

    single_plot(csv_data[0], csv_data[1], "(Optimal) K Value 75 as a Function of Length n (unsorted)", "Line", "N value (x 10 million)")

def sorted_deliverable_1_3():
    csv_data = return_csv_list("deliverable_1.3_csv/sorted_csvs/values.csv", "N") #might need to change to full path

    single_plot(csv_data[0], csv_data[1], "(Optimal) K Value 75 as a Function of Length n (sorted)", "Line", "N value (x 10 million)")
    
unsorted_deliverable_1_3()
sorted_deliverable_1_3()
